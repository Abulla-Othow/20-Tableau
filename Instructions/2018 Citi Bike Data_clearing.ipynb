# %%
import pandas as pd

# %%
cbd1= pd.read_csv('data/JC-201710-citibike-tripdata.csv')

# %%
cbd1.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           410  2017-10-01 00:03:08  2017-10-01 00:09:59              3213
# 1           412  2017-10-01 00:03:13  2017-10-01 00:10:06              3213
# 2           274  2017-10-01 00:24:07  2017-10-01 00:28:42              3195
# 3          2198  2017-10-01 00:31:03  2017-10-01 01:07:42              3199
# 4           166  2017-10-01 00:34:09  2017-10-01 00:36:56              3186
#
#   start station name  start station latitude  start station longitude  \
# 0     Van Vorst Park               40.718489               -74.047727
# 1     Van Vorst Park               40.718489               -74.047727
# 2            Sip Ave               40.730743               -74.063784
# 3       Newport Pkwy               40.728745               -74.032108
# 4      Grove St PATH               40.719586               -74.043117
#
#    end station id    end station name  end station latitude  \
# ...

# %%
cbd1.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd1.head()
# Out:
#    tripDuration            startTime             stopTime  startStationId  \
# 0           410  2017-10-01 00:03:08  2017-10-01 00:09:59            3213
# 1           412  2017-10-01 00:03:13  2017-10-01 00:10:06            3213
# 2           274  2017-10-01 00:24:07  2017-10-01 00:28:42            3195
# 3          2198  2017-10-01 00:31:03  2017-10-01 01:07:42            3199
# 4           166  2017-10-01 00:34:09  2017-10-01 00:36:56            3186
#
#   startStationName  startStationLatitude  startStationLongitude  endStationId  \
# 0   Van Vorst Park             40.718489             -74.047727          3192
# 1   Van Vorst Park             40.718489             -74.047727          3192
# 2          Sip Ave             40.730743             -74.063784          3194
# 3     Newport Pkwy             40.728745             -74.032108          3183
# 4    Grove St PATH             40.719586             -74.043117          3213
#
# ...

# %%
cbd2= pd.read_csv('data/JC-201711-citibike-tripdata.csv')

# %%
cbd2.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           370  2017-11-01 00:04:26  2017-11-01 00:10:37              3199
# 1            96  2017-11-01 00:05:45  2017-11-01 00:07:22              3211
# 2            73  2017-11-01 00:09:49  2017-11-01 00:11:03              3275
# 3           162  2017-11-01 00:14:04  2017-11-01 00:16:47              3275
# 4           214  2017-11-01 00:23:38  2017-11-01 00:27:13              3276
#
#   start station name  start station latitude  start station longitude  \
# 0       Newport Pkwy               40.728745               -74.032108
# 1         Newark Ave               40.721525               -74.046305
# 2     Columbus Drive               40.718355               -74.038914
# 3     Columbus Drive               40.718355               -74.038914
# 4   Marin Light Rail               40.714584               -74.042817
#
#    end station id end station name  end station latitude  \
# ...

# %%
cbd2.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd2.head()
# Out:
#    tripDuration            startTime             stopTime  startStationId  \
# 0           370  2017-11-01 00:04:26  2017-11-01 00:10:37            3199
# 1            96  2017-11-01 00:05:45  2017-11-01 00:07:22            3211
# 2            73  2017-11-01 00:09:49  2017-11-01 00:11:03            3275
# 3           162  2017-11-01 00:14:04  2017-11-01 00:16:47            3275
# 4           214  2017-11-01 00:23:38  2017-11-01 00:27:13            3276
#
#    startStationName  startStationLatitude  startStationLongitude  \
# 0      Newport Pkwy             40.728745             -74.032108
# 1        Newark Ave             40.721525             -74.046305
# 2    Columbus Drive             40.718355             -74.038914
# 3    Columbus Drive             40.718355             -74.038914
# 4  Marin Light Rail             40.714584             -74.042817
#
#    endStationId   endStationName  endStationLatitude  endStationLongitude  \
# ...

# %%
cbd3= pd.read_csv('data/JC-201712-citibike-tripdata.csv')

# %%
cbd3.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           452  2017-12-01 00:00:59  2017-12-01 00:08:32              3183
# 1           159  2017-12-01 00:04:42  2017-12-01 00:07:21              3187
# 2           175  2017-12-01 00:17:00  2017-12-01 00:19:55              3186
# 3           455  2017-12-01 00:50:22  2017-12-01 00:57:57              3194
# 4           670  2017-12-01 00:55:03  2017-12-01 01:06:13              3194
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4    McGinley Square               40.725340               -74.067622
#
#    end station id      end station name  end station latitude  \
# ...

# %%
cbd3.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd3.head()
# Out:
#    tripDuration            startTime             stopTime  startStationId  \
# 0           452  2017-12-01 00:00:59  2017-12-01 00:08:32            3183
# 1           159  2017-12-01 00:04:42  2017-12-01 00:07:21            3187
# 2           175  2017-12-01 00:17:00  2017-12-01 00:19:55            3186
# 3           455  2017-12-01 00:50:22  2017-12-01 00:57:57            3194
# 4           670  2017-12-01 00:55:03  2017-12-01 01:06:13            3194
#
#   startStationName  startStationLatitude  startStationLongitude  endStationId  \
# 0   Exchange Place             40.716247             -74.033459          3199
# 1        Warren St             40.721124             -74.038051          3186
# 2    Grove St PATH             40.719586             -74.043117          3205
# 3  McGinley Square             40.725340             -74.067622          3191
# 4  McGinley Square             40.725340             -74.067622          3189
#
# ...

# %%
cbd4= pd.read_csv('data/JC-201801-citibike-tripdata.csv')

# %%
cbd4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
cbd4.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd4.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId endStationName  endStationLatitude  \
# 0             -74.033459          3199   Newport Pkwy           40.728745
# ...

# %%
cbd5=pd.read_csv('data/JC-201802-citibike-tripdata.csv')

# %%
cbd5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
cbd5.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd5.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId  endStationName  endStationLatitude  \
# 0             -74.033459          3184     Paulus Hook           40.714145
# ...

# %%
cbd6=pd.read_csv('data/JC-201803-citibike-tripdata.csv')

# %%
cbd6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3202     Newport PATH
# ...

# %%
cbd6.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd6.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId endStationName  endStationLatitude  \
# 0             -74.033459          3202   Newport PATH           40.727224
# ...

# %%
cbd7=pd.read_csv('data/JC-201804-citibike-tripdata.csv')

# %%
cbd7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1           298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2          1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3          1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4           559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3638       Washington St
# ...

# %%
cbd7.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd7.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0          1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1           298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2          1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3          1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4           559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId      endStationName  \
# 0             -74.033459          3638       Washington St
# 1             -74.033459          3187           Warren St
# ...

# %%
cbd8=pd.read_csv('data/JC-201805-citibike-tripdata.csv')

# %%
cbd8.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           131  2018-05-01 07:29:57.5490  2018-05-01 07:32:08.6160
# 1            73  2018-05-01 08:13:58.2560  2018-05-01 08:15:11.9230
# 2          4929  2018-05-01 08:17:21.3110  2018-05-01 09:39:31.0770
# 3           432  2018-05-01 08:25:58.7150  2018-05-01 08:33:10.8960
# 4           432  2018-05-01 08:28:09.9160  2018-05-01 08:35:22.1440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
cbd8.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd8.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0           131  2018-05-01 07:29:57.5490  2018-05-01 07:32:08.6160
# 1            73  2018-05-01 08:13:58.2560  2018-05-01 08:15:11.9230
# 2          4929  2018-05-01 08:17:21.3110  2018-05-01 09:39:31.0770
# 3           432  2018-05-01 08:25:58.7150  2018-05-01 08:33:10.8960
# 4           432  2018-05-01 08:28:09.9160  2018-05-01 08:35:22.1440
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId  endStationName  endStationLatitude  \
# 0             -74.033459          3184     Paulus Hook           40.714145
# ...

# %%
cbd9=pd.read_csv('data/JC-201806-citibike-tripdata.csv')

# %%
cbd9.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
cbd9.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd9.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId    endStationName  endStationLatitude  \
# 0             -74.033459          3276  Marin Light Rail           40.714584
# ...

# %%
cbd10=pd.read_csv('data/JC-201807-citibike-tripdata.csv')

# %%
cbd10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
cbd10.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd10.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId  endStationName  endStationLatitude  \
# 0             -74.033459          3183  Exchange Place           40.716247
# ...

# %%
cbd11=pd.read_csv('data/JC-201808-citibike-tripdata.csv')

# %%
cbd11.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
cbd11.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd11.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId   endStationName  endStationLatitude  \
# 0             -74.033459          3270  Jersey & 6th St           40.725289
# ...

# %%
cbd12=pd.read_csv('data/JC-201809-citibike-tripdata.csv')

# %%
cbd12.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3267        Morris Canal
# ...

# %%
cbd12.rename(columns = {'tripduration': 'tripDuration', 'starttime': 'startTime', 
                      'stoptime': 'stopTime', 'start station id': 'startStationId', 'start station name': 'startStationName', 'start station latitude': 'startStationLatitude', 
                      'start station longitude': 'startStationLongitude', 'end station id': 'endStationId', 'end station name': 'endStationName',
                      'end station latitude': 'endStationLatitude', 'end station longitude': 'endStationLongitude', 'bikeid': 'bikeid',
                      'usertype': 'userType', 'birth year': 'birthYear', 'gender': 'gender'}, inplace = True)

# %%
cbd12.head()
# Out:
#    tripDuration                 startTime                  stopTime  \
# 0           284  2018-09-01 01:48:22.0320  2018-09-01 01:53:06.9130
# 1           370  2018-09-01 01:48:22.5010  2018-09-01 01:54:32.9270
# 2          1181  2018-09-01 09:37:04.3070  2018-09-01 09:56:45.3280
# 3           383  2018-09-01 09:44:46.0030  2018-09-01 09:51:09.9230
# 4           377  2018-09-01 09:44:46.1850  2018-09-01 09:51:03.6330
#
#    startStationId startStationName  startStationLatitude  \
# 0            3183   Exchange Place             40.716247
# 1            3183   Exchange Place             40.716247
# 2            3183   Exchange Place             40.716247
# 3            3183   Exchange Place             40.716247
# 4            3183   Exchange Place             40.716247
#
#    startStationLongitude  endStationId      endStationName  \
# 0             -74.033459          3267        Morris Canal
# 1             -74.033459          3214    Essex Light Rail
# ...

# %%
citibike_2018 = pd.concat([cbd1,cbd2,cbd3,cbd4,cbd5,cbd6,cbd7,cbd8,cbd9,cbd10, cbd11, cbd12] )

# %%
citibike_2018.head()
# Out:
#    tripDuration            startTime             stopTime  startStationId  \
# 0           410  2017-10-01 00:03:08  2017-10-01 00:09:59            3213
# 1           412  2017-10-01 00:03:13  2017-10-01 00:10:06            3213
# 2           274  2017-10-01 00:24:07  2017-10-01 00:28:42            3195
# 3          2198  2017-10-01 00:31:03  2017-10-01 01:07:42            3199
# 4           166  2017-10-01 00:34:09  2017-10-01 00:36:56            3186
#
#   startStationName  startStationLatitude  startStationLongitude  endStationId  \
# 0   Van Vorst Park             40.718489             -74.047727          3192
# 1   Van Vorst Park             40.718489             -74.047727          3192
# 2          Sip Ave             40.730743             -74.063784          3194
# 3     Newport Pkwy             40.728745             -74.032108          3183
# 4    Grove St PATH             40.719586             -74.043117          3213
#
# ...

# %%
citibike_2018.to_csv('citibike_2018', sep = ',')

# %%
citibike_2018['gender'].replace([1,2],['Female','Male'],inplace=True)

# %%
citibike_2018.head()
# Out:
#    tripDuration            startTime             stopTime  startStationId  \
# 0           410  2017-10-01 00:03:08  2017-10-01 00:09:59            3213
# 1           412  2017-10-01 00:03:13  2017-10-01 00:10:06            3213
# 2           274  2017-10-01 00:24:07  2017-10-01 00:28:42            3195
# 3          2198  2017-10-01 00:31:03  2017-10-01 01:07:42            3199
# 4           166  2017-10-01 00:34:09  2017-10-01 00:36:56            3186
#
#   startStationName  startStationLatitude  startStationLongitude  endStationId  \
# 0   Van Vorst Park             40.718489             -74.047727          3192
# 1   Van Vorst Park             40.718489             -74.047727          3192
# 2          Sip Ave             40.730743             -74.063784          3194
# 3     Newport Pkwy             40.728745             -74.032108          3183
# 4    Grove St PATH             40.719586             -74.043117          3213
#
# ...

# %%
citibike_2018.to_csv('citibike_2018', sep = ',')

# %%
df=pd.read_csv('citibike_2018')

# %%
df.head()
# Out:
#    Unnamed: 0  tripDuration            startTime             stopTime  \
# 0           0           410  2017-10-01 00:03:08  2017-10-01 00:09:59
# 1           1           412  2017-10-01 00:03:13  2017-10-01 00:10:06
# 2           2           274  2017-10-01 00:24:07  2017-10-01 00:28:42
# 3           3          2198  2017-10-01 00:31:03  2017-10-01 01:07:42
# 4           4           166  2017-10-01 00:34:09  2017-10-01 00:36:56
#
#    startStationId startStationName  startStationLatitude  \
# 0            3213   Van Vorst Park             40.718489
# 1            3213   Van Vorst Park             40.718489
# 2            3195          Sip Ave             40.730743
# 3            3199     Newport Pkwy             40.728745
# 4            3186    Grove St PATH             40.719586
#
#    startStationLongitude  endStationId      endStationName  \
# 0             -74.047727          3192  Liberty Light Rail
# 1             -74.047727          3192  Liberty Light Rail
# ...
